# %% [markdown]
# <a href="https://colab.research.google.com/github/sivasakthi-15/SCT_DS_TASKS/blob/main/SCT_DS_TASKS_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
file_path = "/content/drive/MyDrive/SCT TASKS/ROAD ACCIDENT DATASET.csv"
df = pd.read_csv(file_path)
df
# Out:
#                      States/UTs  \
# 0                Andhra Pradesh
# 1             Arunachal Pradesh
# 2                         Assam
# 3                         Bihar
# 4                  Chhattisgarh
# 5                           Goa
# 6                       Gujarat
# 7                       Haryana
# 8              Himachal Pradesh
# 9             Jammu and Kashmir
# 10                    Jharkhand
# 11                    Karnataka
# 12                       Kerala
# 13               Madhya Pradesh
# 14                  Maharashtra
# 15                      Manipur
# 16                    Meghalaya
# 17                      Mizoram
# 18                     Nagaland
# 19                       Odisha
# 20                       Punjab
# 21                    Rajasthan
# 22                       Sikkim
# 23                   Tamil Nadu
# 24                    Telangana
# 25                      Tripura
# 26                  Uttarakhand
# 27                Uttar Pradesh
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 21 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   States/UTs                                                          37 non-null     object
#  1   State/UT-Wise Total Number of Road Accidents during 2016            37 non-null     int64
#  2   State/UT-Wise Total Number of Road Accidents during 2017            37 non-null     int64
#  3   State/UT-Wise Total Number of Road Accidents during 2018            37 non-null     int64
#  4   State/UT-Wise Total Number of Road Accidents during 2019 - Numbers  37 non-null     int64
#  5   State/UT-Wise Total Number of Road Accidents during 2019 - Rank     36 non-null     float64
#  6   Share of States/UTs in Total Number of Road Accidents - 2016        37 non-null     float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# States/UTs                                                            0
# State/UT-Wise Total Number of Road Accidents during 2016              0
# State/UT-Wise Total Number of Road Accidents during 2017              0
# State/UT-Wise Total Number of Road Accidents during 2018              0
# State/UT-Wise Total Number of Road Accidents during 2019 - Numbers    0
# State/UT-Wise Total Number of Road Accidents during 2019 - Rank       1
# Share of States/UTs in Total Number of Road Accidents - 2016          0
# Share of States/UTs in Total Number of Road Accidents - 2017          0
# Share of States/UTs in Total Number of Road Accidents - 2018          0
# Share of States/UTs in Total Number of Road Accidents - 2019          0
# Total Number of Accidents Per Lakh Population - 2016                  1
# Total Number of Accidents Per Lakh Population - 2017                  1
# Total Number of Accidents Per Lakh Population - 2018                  1
# ...

# %%
states = df["States/UTs"]
years = ["2016", "2017", "2018", "2019"]
accident_counts = df[[
    "State/UT-Wise Total Number of Road Accidents during 2016",
    "State/UT-Wise Total Number of Road Accidents during 2017",
    "State/UT-Wise Total Number of Road Accidents during 2018",
    "State/UT-Wise Total Number of Road Accidents during 2019 - Numbers"
]]
accident_counts.columns = years

# %%
for i, state in enumerate(states[:10]):
  plt.plot(years, accident_counts.iloc[i], marker='o', label=state)
plt.xlabel("Year")
plt.ylabel("Total Accidents")
plt.title("Road Accident Trends (2016-2019) - Top 10 States")
plt.legend()
plt.xticks(years)
plt.show()

# %%
top_states_2019 = accident_counts["2019"].nlargest(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=top_states_2019.values, y=top_states_2019.index, palette="Reds_r")
plt.xlabel("Total Accidents in 2019")
plt.ylabel("States/UTs")
plt.title("Top 10 States with Highest Road Accidents in 2019")
plt.show()
# Out:
# <ipython-input-15-fcc2739fec82>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_states_2019.values, y=top_states_2019.index, palette="Reds_r")

# %%
correlation_matrix = df.select_dtypes(include=['number']).corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap: Accidents, Population & Vehicle Density")
plt.show()
